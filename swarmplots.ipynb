# %%
#EDA
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('olive_train.csv',delimiter=',')

df
# Out:
#      Region  Linoleic acid  Stearic acid
# 0         1    1238.203193    236.944237
# 1         2     772.853826    231.040312
# 2         2    1264.327827    266.618235
# 3         2    1067.605447    208.464492
# 4         2    1344.818202    211.957569
# 5         2    1359.437336    249.118812
# 6         1    1097.289385    236.299666
# 7         2    1113.353073    228.408974
# 8         1    1165.044578    255.038378
# 9         1    1006.287935    213.187577
# 10        1    1138.075582    200.966500
# 11        2     742.219793    241.990795
# 12        1     602.914850    197.560949
# 13        2    1063.712729    252.354509
# 14        1     587.831749    225.316588
# 15        2    1367.005421    255.899391
# 16        1     584.624382    199.198139
# 17        2    1382.184601    245.729321
# 18        1    1005.001140    222.784777
# 19        1     613.426820    205.445337
# 20        1    1177.499480    232.430753
# 21        2     776.416947    253.315714
# ...

# %%
_ = sns.swarmplot(x='Region',y='Linoleic acid', data=df)
_= plt.xlabel('Regions')
_= plt.ylabel('Linoleic acid')
plt.show()

# %%
_ = sns.swarmplot(x='Region',y='Stearic acid', data=df)
_= plt.xlabel('Region')
_= plt.ylabel('Stearic acid')
plt.show()
